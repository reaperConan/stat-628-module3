# %%
import pandas as pd 
from functools import reduce
import string
# from spellchecker import SpellChecker
# spell = SpellChecker()
import nltk
porter = nltk.stem.PorterStemmer()
import numpy as np
import re
pd.options.mode.chained_assignment = None
from nltk.stem.wordnet import WordNetLemmatizer
lem = WordNetLemmatizer()
#nltk.download('wordnet')
import math

# %%
user = pd.read_csv("data/c_user.csv")
tip = pd.read_csv("data/c_tip.csv")
rev = pd.read_csv("data/c_review.csv")
business = pd.read_csv("data/cinema.csv")

# %%
def append(x,y):
    return x+y
def clean(x):
    return list(filter(lambda x: False if x in stop_words or x == '' else True, x))
def word_process(s):
    s = s.translate(str.maketrans('', '', string.punctuation)).lower()
    return lem.lemmatize(s, "v")

# %%
stop_words = pd.read_table("data/stop_words.txt")
stop_words = list(stop_words["words"])

# %%
star = 2
if star != 0 :
    review = rev[rev["stars"] == star]
else:
    review = rev

# %%
word_init = list(map(lambda x: x.replace('no ', 'no').replace('never ', 'never').replace('not ', 'not').replace("n't ", ' not').replace('nt ', ' not').replace("n' ", " not").replace("should ","should").replace("would ", "would").replace('\n', ' ').split(' '), list(review["text"])))

# %%
# sample = list(np.random.choice(len(word_init), size=100, replace=False))
# word = list(map(lambda x: list(map(word_process, x)), list(pd.Series(word_init)[sample])))
word = list(map(lambda x: list(map(word_process, x)), word_init))

# %%
word_clean = list(map(clean, word))

# %%
word_dict = {}
review_list = review
review_list["text"] = pd.Series(word_clean)
for i in list(review.index.values):
    data = review.loc[i]
    if type(data["text"]) == float:
        continue
    count = 1+data["useful"]+data["funny"]+data["cool"]
    time = (np.array('2019-01-01', dtype=np.datetime64)-np.array(review_list.loc[i]["date"].split(" ")[0], dtype=np.datetime64)).astype(dtype=np.float32)
    time_weight = 3-(time/365) if (3-(time/365))  > 0 else 0
    for w in review_list.loc[i]["text"]:
        if not w in word_dict:
            word_dict[w] = 0
        word_dict[w] += count*(0.8+time_weight)
word_dict
# Out:
# {'boyfriend': 46.83013698630136,
#  'sister': 34.534246575342465,
#  'big': 124.786301369863,
#  'gwen': 3.33972602739726,
#  'stefani': 3.33972602739726,
#  'fan': 55.21917808219179,
#  'meet': 66.57808219178084,
#  'greet': 50.76712328767124,
#  'yesterday': 48.40821917808219,
#  'total': 46.38356164383561,
#  'spe': 124.26575342465755,
#  'notwas': 43.276712328767125,
#  '300000': 3.33972602739726,
#  'dollars': 63.44109589041096,
#  '3': 194.83013698630137,
#  'good': 435.6383561643836,
#  'time': 1318.6383561643813,
#  'think': 271.668493150685,
#  'wouldbe': 189.54246575342475,
#  'arrive': 211.31232876712332,
#  'desk': 32.55068493150685,
#  'ticket': 951.6356164383558,
#  'come': 1142.882191780821,
#  'stop': 58.597260273972616,
#  'security': 75.41643835616439,
#  'tell': 946.2246575342463,
#  'wouldnotscan': 3.33972602739726,
#  'notback': 43.38082191780821,
#  'noone': 102.35342465753426,
#  'know': 324.5835616438358,
#  'work': 348.33698630136985,
#  'scramble': 3.33972602739726,
#  'try': 452.9506849315069,
#  'solve': 10.027397260273972,
#  'wad': 7.33972602739726,
#  'employee': 186.5643835616438,
#  'notcome': 45.33972602739725,
#  'now': 336.8904109589041,
#  'wouldmiss': 3.33972602739726,
#  'fro': 335.24109589041103,
#  'notdesk': 93.16164383561642,
#  'wouldresolve': 3.33972602739726,
#  'run': 147.5863013698631,
#  'frantically': 3.33972602739726,
#  'long': 167.4767123287671,
#  'hall': 15.293150684931508,
#  'nothelp': 20.016438356164386,
#  'partner': 3.33972602739726,
#  'ask': 548.8821917808223,
#  'okay': 16.323287671232876,
#  'return': 179.64657534246578,
#  'notthe': 189.4,
#  'actual': 48.00000000000001,
#  'point': 80.30958904109589,
#  'workers': 48.43561643835617,
#  'say': 891.1068493150688,
#  'ga': 8.912328767123288,
#  'stand': 231.50684931506848,
#  'general': 27.920547945205477,
#  'admission': 3.33972602739726,
#  'seat': 1295.101369863011,
#  '27': 3.33972602739726,
#  'mistake': 76.30136986301369,
#  'notexplain': 3.33972602739726,
#  'basically': 38.37534246575343,
#  'embarrass': 31.794520547945204,
#  'nothave': 157.2082191780822,
#  'hand': 94.62739726027398,
#  'gentleman': 19.526027397260272,
#  'credit': 67.27397260273973,
#  'card': 175.0301369863014,
#  'pay': 563.5369863013697,
#  'additional': 27.15342465753425,
#  '700': 8.93972602739726,
#  'purchase': 210.90684931506854,
#  '4000': 3.33972602739726,
#  'later': 200.0575342465753,
#  'want': 259.70410958904114,
#  'embarrassme': 3.33972602739726,
#  'notfrom': 12.23835616438356,
#  'staff': 397.67945205479475,
#  'unprofessionalism': 3.33972602739726,
#  'experience': 563.3753424657534,
#  'notwa': 68.41369863013699,
#  'notto': 616.4191780821918,
#  'disappoi': 6.53972602739726,
#  'notmy': 19.756164383561643,
#  'vip': 105.78082191780821,
#  'lanyards': 3.33972602739726,
#  'posters': 3.33972602739726,
#  'probably': 76.07123287671233,
#  'wouldof': 3.33972602739726,
#  'walk': 426.04657534246576,
#  'sorry': 162.07945205479447,
#  'bad': 286.26027397260276,
#  'review': 235.25205479452052,
#  'felt': 199.8246575342466,
#  'like': 812.3890410958905,
#  'zappos': 3.33972602739726,
#  'better': 305.10136986301353,
#  'consider': 55.56712328767124,
#  'situation': 85.63561643835615,
#  'fault': 18.99178082191781,
#  'amou': 39.87123287671233,
#  'notof': 213.67945205479458,
#  'money': 426.58904109589037,
#  'don': 3.33972602739726,
#  'patterson': 3.33972602739726,
#  'noteven': 203.3150684931507,
#  'begin': 64.2958904109589,
#  'satisfy': 3.5315068493150683,
#  'mind': 44.78356164383561,
#  '4': 97.43561643835615,
#  'month': 76.47945205479454,
#  'baby': 44.24931506849315,
#  'girl': 51.49315068493149,
#  'tonight': 94.38630136986302,
#  'rough': 29.208219178082196,
#  'night': 399.0328767123288,
#  'funny': 9.098630136986301,
#  'chick': 6.284931506849315,
#  'flick': 7.887671232876713,
#  'yes': 123.8301369863014,
#  'notenter': 3.5315068493150683,
#  'wtf': 18.92328767123288,
#  'im': 400.364383561644,
#  'mommmmmy': 3.5315068493150683,
#  'wa': 235.61643835616445,
#  'notme': 12.287671232876711,
#  'just': 1041.8876712328765,
#  'leave': 497.50958904109586,
#  'umm': 3.5315068493150683,
#  'no': 261.1972602739726,
#  'spouse': 3.5315068493150683,
#  'fuck': 16.136986301369863,
#  'form': 6.7315068493150685,
#  'discrimination': 3.5315068493150683,
#  'couple': 71.8027397260274,
#  'wanna': 32.04657534246575,
#  'let': 174.14794520547946,
#  'yall': 6.731506849315068,
#  'decide': 177.82465753424663,
#  'tuesday': 50.37260273972603,
#  'date': 128.39452054794523,
#  'day': 222.53424657534242,
#  'far': 88.81643835616438,
#  'worst': 285.43835616438366,
#  'theater': 1528.512328767122,
#  'life': 94.49863013698629,
#  'noton': 65.97260273972603,
#  'thursday': 37.323287671232876,
#  'bunch': 45.45479452054795,
#  'pimple': 15.200000000000001,
#  'face': 50.08493150684932,
#  'teenagers': 52.178082191780824,
#  'hang': 51.56438356164385,
#  'cuss': 27.879452054794523,
#  'rid': 22.39178082191781,
#  'bike': 15.200000000000001,
#  'talk': 286.8876712328768,
#  'loudly': 18.86849315068493,
#  'doanyway': 15.200000000000001,
#  'upset': 58.76712328767124,
#  'husband': 153.82465753424657,
#  'really': 279.3945205479451,
#  'moviewe': 15.200000000000001,
#  'ridiculous': 102.54520547945206,
#  'pricewalked': 15.200000000000001,
#  'dirty': 283.75068493150695,
#  'entry': 16.0,
#  'way': 383.0520547945205,
#  'gothic': 15.200000000000001,
#  'idiot': 30.89315068493151,
#  'slur': 15.200000000000001,
#  'locatedthe': 15.200000000000001,
#  'popcorn': 669.9287671232876,
#  'look': 373.8438356164386,
#  'roll': 37.07397260273973,
#  'sleep': 20.000000000000004,
#  'bag': 198.18630136986303,
#  'rowthe': 15.200000000000001,
#  'slurpee': 15.200000000000001,
#  'machine': 81.38630136986302,
#  'spat': 15.200000000000001,
#  'outside': 148.80821917808225,
#  'cup': 93.20821917808217,
#  'clean': 360.2356164383562,
#  'cupby': 15.200000000000001,
#  'employers': 15.200000000000001,
#  'kid': 277.7287671232877,
#  'wacked': 15.200000000000001,
#  'surfer': 15.200000000000001,
#  'hair': 86.29041095890415,
#  'feel': 91.52602739726026,
#  'pomeranian': 15.200000000000001,
#  'cystic': 15.200000000000001,
#  'acnethere': 15.200000000000001,
#  'nobeaches': 15.200000000000001,
#  'arizona': 20.8,
#  'surf': 15.200000000000001,
#  'play': 207.22465753424655,
#  'acoustic': 15.200000000000001,
#  'guitar': 15.200000000000001,
#  'taco': 17.967123287671235,
#  'change': 191.7534246575342,
#  'theaters': 249.41917808219176,
#  'small': 171.49315068493152,
#  'crowd': 93.213698630137,
#  'save': 123.44657534246575,
#  'sell': 139.53972602739725,
#  'nottwo': 15.200000000000001,
#  'row': 57.52876712328767,
#  'prepare': 26.400000000000006,
#  'startedthis': 15.200000000000001,
#  'place': 864.1561643835618,
#  'notcool': 24.958904109589042,
#  'lock': 15.200000000000001,
#  'harkins': 162.08219178082192,
#  'wellknown': 15.200000000000001,
#  'use': 481.66575342465774,
#  'favorites': 13.183561643835617,
#  'degrade': 13.183561643835617,
#  'lowest': 16.632876712328766,
#  'quality': 123.74246575342465,
#  'ohio': 13.183561643835617,
#  'aware': 44.18082191780822,
#  'shouldexpect': 13.183561643835617,
#  'expensive': 58.72328767123289,
#  'food': 854.5643835616441,
#  'drink': 438.97260273972597,
#  'unhappy': 16.035616438356165,
#  'members': 41.25205479452055,
#  'concern': 44.81917808219178,
#  'patrons': 41.134246575342466,
#  'facilitate': 13.183561643835617,
#  'young': 101.70958904109588,
#  'person': 292.1506849315069,
#  'understand': 76.32602739726028,
#  'people': 636.2356164383563,
#  'totally': 63.04931506849316,
#  'destroy': 16.964383561643835,
#  'isles': 13.183561643835617,
#  'group': 36.83287671232876,
#  'smoke': 55.317808219178076,
#  'marijuana': 15.583561643835617,
#  'men': 26.59726027397261,
#  'women': 46.98082191780823,
#  'fight': 17.24109589041096,
#  'inside': 170.1041095890411,
#  'sidewalk': 13.183561643835617,
#  'nobody': 17.134246575342466,
#  'care': 108.3945205479452,
#  'nota': 73.2958904109589,
#  'id': 125.35342465753426,
#  'recommend': 89.98904109589043,
#  'bring': 202.8301369863014,
#  'family': 107.80547945205477,
#  'youre': 98.59726027397261,
#  'drive': 124.54794520547948,
#  'extra': 93.80547945205478,
#  'miles': 13.983561643835618,
#  'cinema': 47.10684931506849,
#  'canal': 13.183561643835617,
#  'captain': 18.164383561643838,
#  'america': 18.164383561643838,
#  'civil': 17.364383561643837,
#  'war': 51.780821917808225,
#  'handicap': 64.64383561643835,
#  '5': 213.24657534246572,
#  'buy': 164.49589041095896,
#  'pickle': 17.128767123287673,
#  'sit': 411.213698630137,
#  'right': 298.88767123287676,
#  'movie': 2511.4684931506877,
#  'start': 558.7643835616437,
#  'sixth': 8.564383561643837,
#  'number': 62.013698630136986,
#  'next': 265.7643835616439,
#  'notbother': 28.986301369863014,
#  'assume': 73.86575342465753,
#  'amc': 232.95342465753427,
#  'wouldknow': 8.564383561643837,
#  'boyfriends': 11.764383561643836,
#  'actually': 129.8821917808219,
#  'non': 57.23287671232877,
#  'existent': 8.564383561643837,
#  'proceed': 71.31232876712329,
#  'notwhere': 14.73972602739726,
#  'notify': 19.336986301369866,
#  'existe': 17.128767123287673,
#  'notspot': 14.164383561643838,
#  'hell': 36.52054794520548,
#  'notseat': 24.742465753424657,
#  'middle': 31.098630136986305,
#  'section': 19.76438356164384,
#  'refund': 122.44657534246575,
#  'hi': 14.13972602739726,
#  'youve': 15.558904109589038,
#  'post': 47.953424657534256,
#  'picture': 135.16712328767122,
#  'publicly': 11.43835616438356,
#  'permission': 11.43835616438356,
#  'notappreciate': 11.43835616438356,
#  'cheese': 63.131506849315066,
#  'sauce': 19.97808219178082,
#  'seal': 36.00547945205479,
#  'notsee': 36.87397260273973,
#  'problem': 92.05479452054793,
#  'customers': 228.3068493150685,
#  'eat': 176.25205479452055,
#  'wouldhave': 83.18082191780822,
#  'open': 196.0,
#  'wouldnothave': 13.03835616438356,
#  'noteat': 19.73698630136986,
#  'response': 44.57534246575342,
#  'poor': 170.1260273972603,
#  'management': 18.04931506849315,
#  'notthink': 29.23835616438356,
#  'ive': 218.3369863013699,
#  'droll': 1.9342465753424658,
#  'cashier': 28.731506849315068,
#  'direct': 13.342465753424658,
#  'usher': 64.25479452054793,
#  'hello': 7.298630136986302,
#  'wouldve': 13.55068493150685,
#  'great': 147.268493150685,
#  'never': 614.104109589041,
#  'rude': 361.2794520547947,
#  'glue': 4.309589041095891,
#  'phone': 253.88219178082198,
#  'mass': 1.9342465753424658,
#  'vouchers': 3.8684931506849316,
#  'blair': 1.9342465753424658,
#  'witch': 7.452054794520548,
#  'pre': 8.465753424657533,
#  'screen': 442.0876712328767,
#  'decline': 6.838356164383562,
#  'voucher': 25.01917808219178,
#  'notguranteed': 1.9342465753424658,
#  'notmention': 1.9342465753424658,
#  'shouldarrive': 1.9342465753424658,
#  '2': 328.48493150684953,
#  'hours': 219.87945205479454,
#  'frustrate': 79.37260273972602,
#  'politely': 11.572602739726028,
#  'manager': 583.9479452054793,
#  'kyle': 1.9342465753424658,
#  'inconvenience': 56.783561643835625,
#  'discou': 24.115068493150687,
#  'friend': 103.04109589041097,
#  'refreshments': 5.857534246575343,
#  'receive': 114.31506849315072,
#  'invite': 13.016438356164384,
#  'waste': 132.05479452054794,
#  'efforts': 1.9342465753424658,
#  'poorly': 64.40821917808219,
#  'plan': 32.81917808219178,
#  'theatre': 614.2438356164386,
#  'visit': 140.73972602739724,
#  'palm': 5.934246575342466,
#  'disable': 39.2,
#  'notconfined': 6.4,
#  'wheelchair': 17.6,
#  'notpermitted': 9.167123287671233,
#  'regal': 73.4164383561644,
#  'red': 33.000000000000014,
#  'robin': 6.4,
#  'inform': 81.13424657534247,
#  'thats': 139.64657534246578,
#  'ok': 112.03561643835616,
#  'story': 25.282191780821922,
#  'short': 34.52602739726027,
#  'refuse': 90.26849315068495,
#  'offer': 138.33424657534243,
#  'noti': 53.36164383561644,
#  'state': 85.3041095890411,
#  'nothank': 6.4,
#  'ca': 219.78356164383564,
#  'notwith': 10.545205479452056,
#  'close': 120.26575342465753,
#  'limitations': 6.4,
#  'wouldjust': 8.8,
#  'second': 82.14520547945206,
#  'usually': 51.87123287671232,
#  'prefer': 20.890410958904113,
#  'clerk': 15.712328767123289,
#  'exasperatedly': 6.4,
#  'sigh': 10.432876712328769,
#  'nono': 6.4,
#  'allow': 73.75068493150685,
#  'guess': 109.0986301369863,
#  'whats': 37.89041095890411,
#  'wrong': 104.4904109589041,
#  'locations': 38.55342465753425,
#  'cineplex': 40.38904109589041,
#  'rudest': 2.756164383561644,
#  'employees': 125.43287671232875,
#  'customer': 395.01917808219196,
#  'service': 820.0547945205469,
#  'undergo': 8.509589041095891,
#  'construction': 8.775342465753425,
#  'bite': 112.58356164383561,
#  'harsh': 6.109589041095891,
#  'disorganize': 28.509589041095893,
#  'self': 32.11232876712329,
#  'kiosks': 42.26575342465753,
#  'manage': 23.942465753424656,
#  'assign': 52.22465753424657,
#  'collect': 6.109589041095891,
#  'vain': 6.109589041095891,
#  'various': 13.019178082191782,
#  'type': 46.92054794520548,
#  'include': 42.400000000000006,
#  'imax': 75.96164383561644,
#  'individual': 14.10958904109589,
#  'break': 75.17260273972602,
#  'notin': 79.41917808219179,
#  'end': 190.1753424657534,
#  'notrow': 25.153424657534245,
#  'overhear': 11.238356164383562,
#  'concessionaire': 6.109589041095891,
#  'fine': 129.6712328767123,
#  'recliner': 40.62191780821919,
#  'not': 367.75342465753425,
#  'sure': 151.02191780821917,
#  'watch': 397.47397260273965,
#  'tv': 30.794520547945204,
#  'floor': 216.18904109589047,
#  'directly': 11.709589041095892,
#  'lay': 19.76438356164384,
#  'legs': 6.109589041095891,
#  'underneath': 6.109589041095891,
#  'wouldnotcall': 6.109589041095891,
#  'view': 74.97534246575343,
#  'step': 18.693150684931506,
#  'unwatchable': 11.189041095890412,
#  'disorganization': 6.109589041095891,
#  'apparently': 67.22191780821917,
#  'line': 306.04931506849323,
#  'difficulty': 6.109589041095891,
#  'selfserve': 14.673972602739727,
#  'cash': 78.83835616438357,
#  'notrealize': 17.02191780821918,
#  'clearly': 59.167123287671224,
#  'mark': 10.10958904109589,
#  'wait': 494.2136986301369,
#  '15': 224.3753424657534,
#  'minutes': 602.5945205479455,
#  'pick': 98.45479452054792,
#  'lack': 61.564383561643844,
#  'thereof': 10.10958904109589,
#  'kiosk': 14.673972602739727,
#  'differe': 107.59178082191781,
#  'notshowings': 6.109589041095891,
#  'barely': 23.684931506849317,
#  'make': 342.4739726027397,
#  'head': 68.99178082191781,
#  'snack': 63.72328767123288,
#  'bar': 104.11232876712324,
#  'preview': 74.49589041095889,
#  'issue': 237.123287671233,
#  'nostatic': 6.109589041095891,
#  'menu': 64.31232876712329,
#  'digital': 9.854794520547944,
#  'scroll': 7.413698630136987,
#  'notitems': 7.936986301369863,
#  'information': 29.175342465753427,
#  'real': 42.9013698630137,
#  'challenge': 6.109589041095891,
#  'figure': 21.824657534246576,
#  'price': 237.0931506849315,
#  'concessions': 97.58082191780821,
#  'bathroom': 85.84383561643835,
#  'check': 282.03561643835616,
#  'reason': 100.84657534246577,
#  'helpfully': 6.109589041095891,
#  'misplace': 9.597260273972603,
#  'luckily': 9.30958904109589,
#  'checker': 6.109589041095891,
#  'remember': 16.386301369863016,
#  'traumatize': 6.109589041095891,
#  'infinity': 6.109589041095891,
#  'shouldsee': 6.109589041095891,
#  'proper': 18.597260273972605,
#  'year': 87.47397260273974,
#  'bathrooms': 40.26849315068493,
#  'wouldinvest': 3.6767123287671235,
#  'report': 19.975342465753428,
#  'health': 28.55342465753425,
#  'department': 19.676712328767124,
#  'sad': 66.44383561643836,
#  '20': 184.72054794520545,
#  'groupons': 3.2,
#  'deal': 121.8246575342466,
#  'currently': 7.2,
#  '9115': 3.2,
#  'groupon': 31.567123287671237,
#  'buck': 29.871232876712334,
#  'accou': 15.93972602739726,
#  'notafter': 6.4,
#  'email': 61.65205479452055,
#  'week': 43.06849315068494,
#  'gift': 49.57534246575343,
#  'notsure': 41.364383561643834,
#  'company': 27.575342465753426,
#  'roadhouse': 31.19178082191781,
#  'cinemas': 7.312328767123288,
#  'photo': 3.2,
#  'theatres': 90.32054794520549,
#  'cafe': 7.747945205479452,
#  'performances': 9.994520547945205,
#  'area': 114.84383561643834,
#  'grab': 39.868493150684934,
#  'breakfast': 4.646575342465753,
#  'sandwich': 39.93424657534246,
#  'lunch': 7.830136986301371,
#  'order': 487.85753424657514,
#  'chicken': 64.33150684931506,
#  'cesar': 3.0301369863013696,
#  'man': 75.74246575342465,
#  'oh': 184.82739726027398,
#  'disappointment': 35.1013698630137,
#  'measly': 7.03013698630137,
#  'overprice': 97.5205479452055,
#  'notknow': 129.03835616438357,
#  'require': 14.230136986301371,
#  'bread': 14.808219178082194,
#  '750': 6.035616438356165,
#  'brick': 3.83013698630137,
#  'street': 54.31232876712329,
#  'moneys': 3.0301369863013696,
#  'worth': 77.49863013698629,
#  'rare': 0.8,
#  'formy': 0.8,
#  'steal': 32.21917808219179,
#  'away': 152.1753424657534,
#  'son': 64.94246575342467,
#  'school': 26.964383561643835,
#  'able': 95.84383561643835,
#  'xtra': 0.8,
#  'office': 76.23013698630136,
#  'choose': 41.6958904109589,
#  'location': 91.10684931506847,
#  'convenience': 4.323287671232877,
#  'unfortunately': 54.80000000000002,
#  'taste': 69.69863013698631,
#  'fresh': 34.38904109589041,
#  'old': 145.2164383561644,
#  'mix': 14.857534246575344,
#  'togetherour': 0.8,
#  'soda': 136.0712328767123,
#  '90': 28.635616438356163,
#  'carbonate': 0.8,
#  'water': 201.32328767123286,
#  'hot': 117.11506849315066,
#  'dog': 63.76164383561644,
#  'bun': 3.5835616438356164,
#  'microwave': 8.87123287671233,
#  'poi': 136.15890410958903,
#  'dehydrationunfortunately': 0.8,
#  'items': 76.9205479452055,
#  'settle': 21.545205479452058,
#  'beginningso': 0.8,
#  'course': 38.24383561643835,
#  'notenjoy': 3.6493150684931503,
#  'trash': 122.87397260273971,
#  'endwe': 0.8,
#  'filthiest': 4.164383561643835,
#  '3d': 44.27945205479453,
#  'glass': 117.213698630137,
#  'washroom': 3.3643835616438356,
#  'filthy': 70.95616438356166,
#  'notwithout': 3.3643835616438356,
#  'expectation': 3.3643835616438356,
#  'blemish': 3.3643835616438356,
#  'brand': 11.10958904109589,
#  'luck': 45.043835616438365,
#  'hate': 40.04931506849315,
#  '50': 41.520547945205486,
#  'dece': 24.778082191780825,
#  'notseats': 9.087671232876712,
#  'online': 92.7041095890411,
#  '67': 2.4000000000000004,
#  'stick': 67.76712328767124,
#  'transaction': 2.4000000000000004,
#  'fee': 27.28219178082192,
#  'excite': 35.326027397260276,
#  'closer': 8.402739726027397,
#  'buckeye': 2.4000000000000004,
#  'ill': 112.35068493150683,
#  'continue': 34.73972602739726,
#  'absolute': 21.873972602739727,
#  'encounter': 37.21643835616439,
#  'problems': 20.032876712328772,
#  'stub': 8.86027397260274,
#  'reward': 13.523287671232879,
#  'movies': 171.86575342465753,
#  'dec': 6.5260273972602745,
#  '3rd': 45.895890410958906,
#  'concession': 141.52328767123285,
#  'birthday': 30.071232876712333,
#  'large': 107.79452054794521,
#  'charge': 136.04383561643837,
#  'years': 159.8410958904109,
#  'notagain': 6.4,
#  'literally': 50.68767123287671,
#  'days': 50.87671232876713,
#  'notable': 26.400000000000002,
#  'reimburse': 4.800000000000001,
#  'lie': 14.065753424657535,
#  'scum': 4.800000000000001,
#  'thiefs': 4.800000000000001,
#  'honestly': 81.42191780821918,
#  'hope': 53.994520547945214,
#  'shut': 14.47123287671233,
#  'cancel': 40.91506849315068,
#  'membership': 32.898630136986306,
#  'hill': 17.30958904109589,
#  'normal': 20.750684931506846,
#  'exhibit': 50.082191780821915,
#  'resort': 34.060273972602744,
#  'wo': 171.61917808219178,
#  'notbe': 131.22191780821916,
#  'renew': 9.04109589041096,
#  'stupid': 44.96164383561644,
#  'station': 52.709589041095896,
#  'casinos': 16.843835616438355,
#  'guests': 53.545205479452065,
#  'consession': 3.2,
#  'guy': 164.5863013698631,
#  'unprofessional': 39.4027397260274,
#  'ghetto': 31.85753424657534,
#  'super': 52.59452054794521,
#  'suck！！！！probabely': 1.7232876712328766,
#  'sept': 1.7232876712328766,
#  '22，but': 1.7232876712328766,
#  'scan': 20.78082191780822,
#  'checkpoint，its': 1.7232876712328766,
#  'threatre，but': 1.7232876712328766,
#  'screen，someone': 1.7232876712328766,
#  'seat，and': 1.7232876712328766,
#  'double': 63.18630136986302,
#  'ticket，and': 1.7232876712328766,
#  'today，sept': 1.7232876712328766,
#  '23rd，but': 1.7232876712328766,
#  'hey': 36.05205479452055,
#  'excuse': 48.58630136986301,
#  'today': 102.61917808219177,
#  '22nd': 1.7232876712328766,
#  'pizza': 50.11780821917807,
#  'icee': 14.523287671232877,
#  'ready': 35.15068493150685,
#  'enjoy': 187.76986301369868,
#  'notfor': 20.057534246575344,
#  'kick': 40.14794520547946,
#  'out！！': 1.7232876712328766,
#  'awful': 121.25205479452053,
#  'threatre': 1.7232876712328766,
#  'ever！': 1.7232876712328766,
#  'maybe': 106.25479452054792,
#  'none': 15.698630136986303,
#  'attendants': 4.58082191780822,
#  'notwere': 4.58082191780822,
#  'helpful': 13.945205479452056,
#  'question': 51.983561643835614,
#  'zero': 41.224657534246575,
#  'entire': 143.47123287671235,
#  'reserve': 47.29315068493151,
#  'noproblem': 16.915068493150685,
#  'twice': 92.28767123287672,
#  'force': 8.18082191780822,
#  'lady': 122.2904109589041,
#  'nother': 2.4000000000000004,
#  'manageme': 195.86027397260278,
#  'notdid': 2.4000000000000004,
#  'sisters': 12.465753424657535,
#  'daughters': 2.4000000000000004,
#  'notbecause': 2.4000000000000004,
#  'nomore': 2.4000000000000004,
#  'notabout': 19.876712328767123,
#  'fact': 41.16438356164384,
#  'instead': 151.83013698630134,
#  'responsibility': 2.4000000000000004,
#  'systems': 10.47123287671233,
#  'wouldnoteven': 8.0,
#  'harass': 5.887671232876713,
#  'liars': 2.4000000000000004,
#  'notis': 39.53972602739726,
#  'horrible': 384.1561643835618,
#  'comdenscending': 2.4000000000000004,
#  'community': 4.800000000000001,
#  'grow': 3.2821917808219183,
#  'thrive': 2.4000000000000004,
#  'westgate': 55.63013698630137,
#  'extremely': 135.28767123287665,
#  'condescend': 11.917808219178083,
#  'environme': 11.287671232876711,
#  'notthat': 32.846575342465755,
#  'nofamily': 2.4000000000000004,
#  'shouldbe': 59.865753424657534,
#  'love': 144.07671232876714,
#  'goodyear': 2.4000000000000004,
#  'notbeat': 2.5205479452054798,
#  'customary': 2.5205479452054798,
#  'sarcastic': 2.5205479452054798,
#  'comment': 8.531506849315068,
#  'breath': 10.175342465753424,
#  'misunderstand': 3.8794520547945206,
#  'greg': 2.5205479452054798,
#  'procedure': 2.5205479452054798,
#  'wouldthink': 30.18904109589041,
#  'reiterate': 2.5205479452054798,
#  'notway': 2.5205479452054798,
#  'example': 3.3205479452054796,
#  'early': 139.14246575342466,
#  'prior': 43.008219178082186,
#  'code': 16.306849315068494,
#  'safety': 28.542465753424658,
#  'need': 223.36986301369873,
#  'notassume': 5.0410958904109595,
#  'fiancé': 16.345205479452055,
#  'determine': 2.5205479452054798,
#  'max': 18.6986301369863,
#  'occupancy': 2.5205479452054798,
#  'god': 29.95068493150685,
#  'las': 65.24109589041096,
#  'vegas': 143.27945205479452,
#  'strip': 45.62465753424658,
#  'suppose': 44.72328767123287,
#  'nice': 137.4164383561644,
#  'pad': 9.616438356164384,
#  'dissolve': 9.616438356164384,
#  'metal': 19.232876712328768,
#  'wire': 19.232876712328768,
#  '30': 129.73150684931508,
#  'painful': 9.616438356164384,
#  'cut': 143.17534246575343,
#  'circulation': 19.232876712328768,
#  'foreward': 9.616438356164384,
#  'ruin': 112.5178082191781,
#  'freak': 24.073972602739723,
#  'hardly': 45.03835616438356,
#  'attention': 35.035616438356165,
#  'halfway': 36.1972602739726,
#  'pain': 23.786301369863015,
#  'offand': 9.616438356164384,
#  'absolutely': 125.29863013698629,
#  'disguistinglike': 9.616438356164384,
#  'wouldexpect': 60.11780821917807,
#  'nasty': 34.227397260273975,
#  'dive': 9.616438356164384,
#  'barit': 9.616438356164384,
#  'despicable': 9.616438356164384,
#  'complain': 98.99178082191781,
#  'laugh': 26.43013698630137,
#  'yea': 9.616438356164384,
#  'cute': 10.416438356164385,
#  'free': 141.05479452054794,
#  'pass': 155.15890410958906,
#  'wouldnotwa': 9.616438356164384,
#  'local': 17.802739726027397,
#  'notcute': 9.616438356164384,
#  'poke': 9.616438356164384,
#  'ass': 26.14246575342466,
#  'nottheater': 22.871232876712327,
#  'mean': 140.20000000000002,
#  'notcheap': 27.87945205479452,
#  'youll': 44.75068493150684,
#  'piss': 20.150684931506852,
#  'nothardly': 9.616438356164384,
#  'concentrate': 9.616438356164384,
#  'discomfort': 9.616438356164384,
#  'grandkids': 24.8,
#  'phx': 26.400000000000002,
#  'science': 55.199999999999996,
#  'center': 65.24931506849315,
#  'ago': 69.32054794520548,
#  'disappoint': 230.44109589041105,
#  'notworking': 30.4,
#  'mess': 96.90136986301368,
#  'noemployees': 24.8,
#  'vandalize': 24.8,
#  'museum': 28.000000000000004,
#  '60': 32.86027397260274,
#  'rip': 65.4027397260274,
#  'december': 2.8547945205479452,
#  'joke': 50.86027397260274,
#  '114': 9.684931506849315,
#  'ac': 31.520547945205482,
#  'toddlers': 10.567123287671233,
#  'drip': 12.884931506849316,
#  'sweat': 9.684931506849315,
#  'soak': 11.715068493150685,
#  'lobby': 98.27397260273973,
#  'disgust': 68.64657534246575,
#  'overflow': 24.38082191780822,
#  'table': 77.69041095890411,
#  'notbeen': 41.68493150684931,
#  'weeks': 39.347945205479455,
#  'cheap': 58.44109589041096,
#  'mainplace': 9.684931506849315,
#  'santa': 9.684931506849315,
#  'ana': 9.684931506849315,
#  'learn': 53.8054794520548,
#  'thing': 137.37260273972606,
#  'new': 159.50410958904112,
#  'tropicana': 6.564383561643835,
#  'final': 12.164383561643834,
#  'sadly': 19.016438356164382,
#  'discriminate': 14.893150684931506,
#  'turn': 255.59178082191778,
#  'ritz': 6.564383561643835,
#  'crackers': 32.821917808219176,
#  'purse': 40.517808219178086,
#  'enter': 47.2,
#  'build': 51.57260273972604,
#  'nottrying': 9.416438356164383,
#  'hide': 11.591780821917808,
#  'hold': 107.18356164383563,
#  'hes': 11.016438356164382,
#  'diabetic': 17.62191780821918,
#  'blood': 12.164383561643834,
#  'sugar': 6.564383561643835,
#  'drop': 96.68219178082191,
#  'low': 49.96164383561643,
#  'doctor': 8.164383561643834,
#  'carry': 22.71780821917808,
#  'imagine': 28.134246575342466,
#  'notbring': 29.879452054794523,
#  'notlike': 25.435616438356163,
#  'chip': 16.624657534246577,
#  'candy': 50.07123287671234,
#  'gum': 6.564383561643835,
#  'speak': 130.08219178082194,
#  'cameras': 6.564383561643835,
#  'saw': 97.7260273972603,
#  'owner': 49.331506849315076,
#  'wouldget': 28.83013698630137,
#  'mad': 21.402739726027395,
#  'lose': 102.02191780821917,
#  'loyal': 6.564383561643835,
#  'petty': 8.964383561643835,
#  'notfair': 8.964383561643835,
#  'notgo': 76.64109589041097,
#  'till': 14.526027397260275,
#  'incompete': 11.358904109589043,
#  'notworkers': 4.610958904109589,
#  'comedic': 0.8,
#  'light': 356.5972602739725,
#  'interact': 0.8,
#  'humans': 0.8,
#  'ugh': 46.29041095890412,
#  'inappropriate': 9.860273972602739,
#  'lackluster': 18.986301369863014,
#  'skills': 14.67945205479452,
#  'groom': 0.8,
#  'eve': 12.0,
#  'tix': 0.8,
#  '645': 0.8,
#  'pm': 69.28219178082193,
#  'film': 210.2191780821918,
#  'adults': 20.416438356164385,
#  'diet': 9.808219178082194,
#  'coke': 24.284931506849308,
#  '36': 0.8,
#  'mins': 76.95890410958903,
#  'hour': 118.12876712328763,
#  'notstand': 11.717808219178082,
#  'mome': 61.35616438356165,
#  'abhorre': 3.2,
#  'notslow': 0.8,
#  'write': 84.9260273972603,
#  'act': 103.13150684931506,
#  'attempt': 16.0,
#  'member': 25.635616438356166,
#  'box': 101.84931506849315,
#  'easy': 10.400000000000002,
#  'feat': 1.6,
#  'hu': 0.8,
#  'approach': 22.586301369863012,
#  'woman': 37.88219178082193,
#  'kind': 68.92876712328767,
#  'hat': 48.46027397260274,
#  'notgoing': 28.578082191780823,
#  'reply': 35.065753424657544,
#  'choice': 13.76164383561644,
#  'notlet': 18.536986301369865,
#  'anymore': 61.345205479452055,
#  'underwhelmed': 4.0,
#  'high': 52.37534246575342,
#  'neighborhood': 11.200000000000001,
#  'summerlin': 0.8,
#  'hopefully': 28.93150684931507,
#  'sophisticate': 0.8,
#  'friendly': 23.819178082191783,
#  'entity': 0.8,
#  'feature': 12.846575342465755,
#  'smaller': 21.265753424657536,
#  'indie': 4.10958904109589,
#  'foreign': 0.8,
#  'landmark': 0.8,
#  'los': 6.139726027397261,
#  'angeles': 2.4000000000000004,
#  'appare': 4.0,
#  'notcannothire': 0.8,
#  'enthusiastic': 0.8,
#  'appropriate': 0.8,
#  'venues': 12.205479452054796,
#  'shame': 28.69315068493151,
#  'power': 2.4000000000000004,
#  'notbeing': 39.4986301369863,
#  'things': 143.20821917808217,
#  'antiquate': 6.526027397260274,
#  'major': 33.726027397260275,
#  'renovation': 24.27945205479452,
#  'unattractive': 6.526027397260274,
#  'bore': 13.134246575342466,
#  'stall': 25.45205479452055,
#  'presence': 12.353424657534246,
#  'main': 19.663013698630138,
#  'entrance': 50.46849315068493,
#  'alley': 12.95890410958904,
#  'showtime': 15.556164383561644,
#  'nopreviews': 6.526027397260274,
#  'dead': 15.03013698630137,
#  'silence': 9.312328767123287,
#  'awkwardness': 6.526027397260274,
#  'advice': 15.906849315068492,
#  'premiere': 15.161643835616436,
#  'deadpool': 16.72054794520548,
#  '7': 51.59452054794521,
#  'notrealizing': 2.5315068493150683,
#  'pdx': 2.5315068493150683,
#  'premium': 37.19178082191781,
#  'impress': 20.780821917808222,
#  'monitor': 21.51232876712329,
#  'nolarger': 2.5315068493150683,
#  'standard': 30.147945205479452,
#  'special': 21.668493150684935,
#  'sound': 209.30958904109593,
#  'notrecommend': 88.9095890410959,
#  'shell': 2.5315068493150683,
#  '7pm': 12.284931506849315,
#  'friday': 59.38630136986302,
#  'theyre': 38.71506849315069,
#  'vines': 3.747945205479452,
#  'limit': 27.041095890410958,
#  'selection': 5.627397260273973,
#  'notmany': 3.747945205479452,
#  'options': 29.86027397260274,
#  'should': 10.147945205479454,
#  'notthey': 11.997260273972604,
#  'fully': 30.408219178082195,
#  'stock': 16.547945205479454,
#  'rock': 17.649315068493152,
#  'weekend': 46.468493150684935,
#  'mention': 52.684931506849324,
#  'foyer': 3.747945205479452,
#  'litter': 12.975342465753425,
#  'alternate': 3.747945205479452,
#  'future': 53.276712328767125,
#  'notgive': 14.635616438356166,
#  'star': 142.18904109589042,
#  'yelp': 54.68767123287671,
#  'reality': 4.0,
#  'stude': 17.545205479452058,
#  'notfield': 4.0,
#  'trip': 57.74246575342465,
#  'book': 99.12602739726027,
#  'warn': 38.509589041095886,
#  'notdo': 25.734246575342468,
#  'worse': 65.57808219178082,
#  'teach': 5.6,
#  'classroom': 4.0,
#  'field': 18.4,
#  'range': 6.4,
#  'nocalls': 4.0,
#  'transfer': 10.4,
#  'answer': 80.42465753424658,
#  'dial': 13.956164383561646,
#  'tone': 10.44109589041096,
#  'arghhh': 4.0,
#  'frustration': 13.076712328767124,
#  'abound': 4.0,
#  'teachers': 4.0,
#  'title': 4.0,
#  'worthless': 4.0,
#  'class': 25.808219178082197,
#  'exceptions': 4.0,
#  'educators': 8.0,
#  'reallytimes2': 4.0,
#  'slap': 6.838356164383562,
#  'wouldtake': 8.0,
#  'explain': 105.66849315068492,
#  'rest': 92.38356164383562,
#  'assure': 39.2,
#  'world': 33.660273972602745,
#  'months': 13.600000000000001,
#  'finally': 166.65479452054794,
#  'noexcuse': 5.413698630136986,
#  ...}

# %%
# count_filter = pd.Series(word_dict) >= sorted(list(word_dict.values()))[-50]
# count_filter = count_filter.reset_index()[0]
# pd.Series(list(word_dict.keys()))[count_filter]
def word_dict_fx(key):
    return word_dict[key]

# %%
hp_word = sorted(list(word_dict.keys()), key=word_dict_fx, reverse = True)
hp_word_count = pd.Series(word_dict)[hp_word]

# %%
import csv
w = csv.writer(open("word_count/output" + str(star) + ".csv", "w"))
for key, val in hp_word_count.items():
    w.writerow([key, val])
